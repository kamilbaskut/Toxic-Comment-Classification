# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Read Preprocessed Data

# %%
data = pd.read_csv(r'drive/My Drive/Doğal Dil İşleme/preprocessed_data.csv')

# %%
x_data = data["text"]
y_data = data["target"]

# %%
x_data
# Out:
# 0                           haha you guy are bunch of loser
# 1                                         ur sh tty comment
# 2         it ridiculous that these guy are being called ...
# 3         this story get more ridiculous by the hour and...
# 4         angry troll misogynist and racist oh my it doe...
#                                 ...
# 319251    more evidence that trump is in his heart of he...
# 319252    i definitely did not like him in life or in th...
# 319253    yes they did oppose everything he did because ...
# 319254    barney clyde cartoon strip below the letter to...
# 319255    but what about her email that why they voted f...
# Name: text, Length: 319256, dtype: object

# %% [markdown]
# # BERT

# %%
pip install bert_embedding
# Out:
# ...
#      |████████████████████████████████| 215kB 10.9MB/s
# ...
#      |████████████████████████████████| 13.8MB 325kB/s
# ...
#      |████████████████████████████████| 29.6MB 149kB/s
# ...
#   Created wheel for gluonnlp: filename=gluonnlp-0.6.0-cp36-none-any.whl size=259916 sha256=690edf353a497c77cb8433e6441bd3d819480dc64cc865d024f176d7b715c6a9
#   Stored in directory: /root/.cache/pip/wheels/ff/48/ac/a77c79aa416ba6dd7bf487f2280b0471034f66141617965914
# Successfully built gluonnlp
# ERROR: xarray 0.15.1 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# ERROR: umap-learn 0.4.6 has requirement numpy>=1.17, but you'll have numpy 1.14.6 which is incompatible.
# ERROR: tifffile 2020.9.3 has requirement numpy>=1.15.1, but you'll have numpy 1.14.6 which is incompatible.
# ERROR: tensorflow 2.3.0 has requirement numpy<1.19.0,>=1.16.0, but you'll have numpy 1.14.6 which is incompatible.
# ...

# %%
from bert_embedding import BertEmbedding

# %%
bert = BertEmbedding()
# Out:
# Vocab file is not found. Downloading.
# ...

# %%
X = bert(x_data)

# %%
X

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y_data, test_size=0.2, random_state=32)

# %%
np.unique(y_test, return_counts=True)

# %% [markdown]
# # Sklearn

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# %%
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
model.score(x_test, y_test)

# %%
model = AdaBoostClassifier()
# %time
model.fit(x_train, y_train)
model.score(x_test, y_test)

# %%
model = RandomForestClassifier()
# %time
model.fit(x_train, y_train)
model.score(x_test, y_test)

# %%
model = SVC()
# %time
model.fit(x_train, y_train)
model.score(x_test, y_test)

# %%
model = KNeighborsClassifier()
# %time
model.fit(x_train, y_train)
model.score(x_test, y_test)

# %%
model = GaussianNB()
# %time
model.fit(x_train, y_train)
model.score(x_test, y_test)

# %% [markdown]
# # XGBOOST

# %%
import xgboost

# %%
model = xgboost.XGBClassifier(updater='grow_gpu')
# %time
model.fit(x_train, y_train )
model.score(x_train, y_train)

# %% [markdown]
# # Neural Network

# %%
from keras.layers import Dense
from keras.models import Sequential

# %%
model = Sequential()

model.add(Embedding(input_dim=1024 ,output_dim= 128, input_length=1500))
model.add(Dense(1024, input_dim =1500, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()

# %%
hist = model.fit(x_train, y_train, batch_size=64, epochs=30, validation_split=0.1)

# %%
model.evaluate(x_test, y_test)[1]

# %% [markdown]
# # LSTM

# %%
from keras.layers import LSTM
from keras.layers import Embedding

model = Sequential()

model.add(Embedding(input_dim=1024 ,output_dim= 128, input_length=1500))
model.add(LSTM(64))
model.add(Dense(8))
model.add(Dense(1, activation="sigmoid"))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()

# %%
hist = model.fit(x_train, y_train, batch_size=64, epochs=30, validation_split=0.1)
